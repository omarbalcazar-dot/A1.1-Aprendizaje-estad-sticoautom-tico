# %% [markdown]
# En esta celda puse la libreria pandas, que hace trabajar con datos en forma de tablas.
#
# Se carga el archivo Obesidad.csv usando read_csv().
#
# Use head(10) para ver las primeras 10 filas.

# %%
import pandas as pd
df = pd.read_csv("Obesidad.csv")
df.head(10)
# Out:
#      Sexo  Edad  Estatura  Peso FamiliarConSobrepeso ComeMuchasCalorias  \
# 0  Female  21.0      1.62  64.0                  yes                 no
# 1  Female  21.0      1.52  56.0                  yes                 no
# 2    Male  23.0      1.80  77.0                  yes                 no
# 3    Male  27.0      1.80  87.0                   no                 no
# 4    Male  22.0      1.78  89.8                   no                 no
# 5    Male  29.0      1.62  53.0                   no                yes
# 6  Female  23.0      1.50  55.0                  yes                yes
# 7    Male  22.0      1.64  53.0                   no                 no
# 8    Male  24.0      1.78  64.0                  yes                yes
# 9    Male  22.0      1.72  68.0                  yes                yes
#
#    ComeVegetales Fumador  ConsumoDeAgua      NivelDeObesidad
# 0            2.0      no            2.0        Normal_Weight
# ...

# %% [markdown]
# Si estuviera en el equipo de investigacion, mediria la actividad fisica semanal (horas de ejercicio a la semana). Seria una variable cuantitativa, porque expresa como un número que indica horas de ejercicio.

# %% [markdown]
# En esta celda escogi la variable de NivelDeObesidad como salida, ya que es el objetivo principal del estudio.
# Como es una variable cualitativa, uso value_counts() para contar cuantas personas pertenecen a cada categoria.

# %%
sal = df["NivelDeObesidad"]
sal.value_counts()
# Out:
# NivelDeObesidad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# En esta celda hice una grafica de dispersion de la poblacion masculina.
# El eje X representa el peso y el eje Y el nivel de obesidad.
#
# Utilice el alpha para hacer los puntos mas transparentes, para que sea mas facil de visualizar.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

df_fem = df[df["Sexo"] == "Male"]

plt.scatter(df_fem["Peso"], df_fem["NivelDeObesidad"], alpha= 0.1)
plt.xlabel("Peso (kg)")
plt.ylabel("Nivel de Obesidad")
plt.title("Relacion Peso - Nivel de Obesidad (Masculino)")
plt.show()
